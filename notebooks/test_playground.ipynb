# %% [markdown]
# # Test Playground: A place to try out our ideas in a notebook!

# %% [markdown]
# This is a place where we want to try out new ideas with test scripts for data analysis of FED-related data.

# %% [markdown]
# ### Import libraries of interest

# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt
import os
pd.set_option('display.max_rows', None)

# %%
#############################################################################   
#####################################################
# FUNCTION TO READ AND SORT EACH MOUSE DATA, 
# AND TO GET ALL MICE IDS

def read_csv_files(file_path):
        # reads csv files and organizes them into dataframes
        
        all_dataframes = []
        # for all files in folder
        for file in os.listdir(file_path):
            if file.endswith(".CSV"):
                if file.startswith("FED"):
                    # read that file into a dataframe
                    file_path_df = os.path.join(file_path ,file)
                    df = pd.read_csv(file_path_df)
                    all_dataframes.append(df)
##################################################                    
        # create a single dataframe from all files
        singular_df = pd.concat(all_dataframes).sort_values(by=['MM:DD:YYYY hh:mm:ss'])
        return singular_df

# %%
concat_df = read_csv_files('/Users/kevinmcpherson/github-projects/fed-scripts/data/FED001')
concat_df.to_csv('/Users/kevinmcpherson/github-projects/fed-scripts/concat_data/FED001_concat.csv')

# %%
start_time = input("Enter the date and start time (YYYY-MM-DD hh:mm:ss, e.g., 2023-05-01 10:00:00): ")
start_time = dt.strptime(start_time, '%Y-%m-%d %H:%M:%S')
print(start_time)
# Out:
# 2022-06-16 12:00:00

# %% [markdown]
# ### Import a sample piece of data

# %%
# # Import the data, or read from Dropbox
# df = pd.read_csv('~/github-projects/fed-scripts/data/FED001_061622_00.CSV')
# # df = df.concat('','','')
# df

# %% [markdown]
# ### Make time column datetime object

# %%
concat_df['MM:DD:YYYY hh:mm:ss'] = pd.to_datetime(concat_df['MM:DD:YYYY hh:mm:ss'])
concat_df['Time Delta'] = concat_df['MM:DD:YYYY hh:mm:ss'] - start_time
concat_df.head()
# Out:
#   MM:DD:YYYY hh:mm:ss Library_Version Session_type  Device_Number  \
# 0 2022-06-16 14:14:23          1.12.0   ClosedEcon             13
# 1 2022-06-16 14:14:41          1.12.0   ClosedEcon             13
# 2 2022-06-16 14:14:49          1.12.0   ClosedEcon             13
# 3 2022-06-16 15:27:35          1.12.0   ClosedEcon             13
# 4 2022-06-16 15:27:36          1.12.0   ClosedEcon             13
#
#    Battery_Voltage  Motor_Turns  FR   Event Active_Poke  Left_Poke_Count  \
# 0             4.01          NaN   1   Right        Left                0
# 1             4.01          NaN   1    Left        Left                1
# 2             4.01          1.0   1  Pellet        Left                1
# 3             4.00          NaN   1    Left        Left                2
# 4             4.00          1.0   1  Pellet        Left                2
#
#    Right_Poke_Count  Pellet_Count  Block_Pellet_Count Retrieval_Time  \
# 0                 1             0                   0            NaN
# 1                 1             0                   0            NaN
# 2                 1             1                   1           6.91
# 3                 1             1                   0            NaN
# 4                 1             2                   1           0.52
#
#    InterPelletInterval  Poke_Time      Time Delta
# 0                  NaN       0.22 0 days 02:14:23
# 1                  NaN       0.10 0 days 02:14:41
# 2                  NaN        NaN 0 days 02:14:49
# 3                  NaN       0.40 0 days 03:27:35
# 4               4367.0        NaN 0 days 03:27:36

# %% [markdown]
# ### For now, find out where the file starts and ends

# %%
print('The file starts at', concat_df['MM:DD:YYYY hh:mm:ss'].iloc[0])
print('The file ends at', concat_df['MM:DD:YYYY hh:mm:ss'].iloc[-1])

print('The file starts at', concat_df['Time Delta'].iloc[0])
print('The file ends at', concat_df['Time Delta'].iloc[-1])
# Out:
# The file starts at 2022-06-16 14:14:23
# The file ends at 2022-07-06 09:49:18
# The file starts at 0 days 02:14:23
# The file ends at 19 days 21:49:18

# %%
bin_ends = list(pd.timedelta_range(start='0 days 00:12:00', end='20 days 00:00:00', freq='24H'))
bin_ends_series = pd.Series(bin_ends)

# %%
concat_df.head()
# Out:
#   MM:DD:YYYY hh:mm:ss Library_Version Session_type  Device_Number  \
# 0 2022-06-16 14:14:23          1.12.0   ClosedEcon             13
# 1 2022-06-16 14:14:41          1.12.0   ClosedEcon             13
# 2 2022-06-16 14:14:49          1.12.0   ClosedEcon             13
# 3 2022-06-16 15:27:35          1.12.0   ClosedEcon             13
# 4 2022-06-16 15:27:36          1.12.0   ClosedEcon             13
#
#    Battery_Voltage  Motor_Turns  FR   Event Active_Poke  Left_Poke_Count  \
# 0             4.01          NaN   1   Right        Left                0
# 1             4.01          NaN   1    Left        Left                1
# 2             4.01          1.0   1  Pellet        Left                1
# 3             4.00          NaN   1    Left        Left                2
# 4             4.00          1.0   1  Pellet        Left                2
#
#    Right_Poke_Count  Pellet_Count  Block_Pellet_Count Retrieval_Time  \
# 0                 1             0                   0            NaN
# 1                 1             0                   0            NaN
# 2                 1             1                   1           6.91
# 3                 1             1                   0            NaN
# 4                 1             2                   1           0.52
#
#    InterPelletInterval  Poke_Time      Time Delta
# 0                  NaN       0.22 0 days 02:14:23
# 1                  NaN       0.10 0 days 02:14:41
# 2                  NaN        NaN 0 days 02:14:49
# 3                  NaN       0.40 0 days 03:27:35
# 4               4367.0        NaN 0 days 03:27:36

# %%
def convert_to_hours(delta):
    total_seconds = delta.total_seconds()
    hours = str(int(total_seconds // 3600)).zfill(2)
    minutes= str(int((total_seconds % 3600) // 60)).zfill(2)
    seconds = str(int(total_seconds % 60)).zfill(2)
    return f"{hours}:{minutes}:{seconds}"

def extract_hours(time_delta):
    hours_int = int(time_delta.split(':')[0])
    return hours_int

# %%
concat_df['Time Delta Reformatted'] = concat_df['Time Delta'].apply(convert_to_hours)
concat_df['Hours Since Start'] = concat_df['Time Delta Reformatted'].apply(extract_hours)
concat_df.head()
# Out:
#   MM:DD:YYYY hh:mm:ss Library_Version Session_type  Device_Number  \
# 0 2022-06-16 14:14:23          1.12.0   ClosedEcon             13
# 1 2022-06-16 14:14:41          1.12.0   ClosedEcon             13
# 2 2022-06-16 14:14:49          1.12.0   ClosedEcon             13
# 3 2022-06-16 15:27:35          1.12.0   ClosedEcon             13
# 4 2022-06-16 15:27:36          1.12.0   ClosedEcon             13
#
#    Battery_Voltage  Motor_Turns  FR   Event Active_Poke  Left_Poke_Count  \
# 0             4.01          NaN   1   Right        Left                0
# 1             4.01          NaN   1    Left        Left                1
# 2             4.01          1.0   1  Pellet        Left                1
# 3             4.00          NaN   1    Left        Left                2
# 4             4.00          1.0   1  Pellet        Left                2
#
#    Right_Poke_Count  Pellet_Count  Block_Pellet_Count Retrieval_Time  \
# 0                 1             0                   0            NaN
# 1                 1             0                   0            NaN
# 2                 1             1                   1           6.91
# 3                 1             1                   0            NaN
# 4                 1             2                   1           0.52
#
#    InterPelletInterval  Poke_Time      Time Delta Time Delta Reformatted  \
# 0                  NaN       0.22 0 days 02:14:23               02:14:23
# 1                  NaN       0.10 0 days 02:14:41               02:14:41
# 2                  NaN        NaN 0 days 02:14:49               02:14:49
# 3                  NaN       0.40 0 days 03:27:35               03:27:35
# 4               4367.0        NaN 0 days 03:27:36               03:27:36
#
#    Hours Since Start
# 0                  2
# 1                  2
# 2                  2
# 3                  3
# 4                  3

# %%
# def create_bins(time_period_var, time_delta_series):
#     
#     hour_end = int(time_delta_series.loc[-1].split(':')[0])
#     for i in range(0, hour_end, time_period_var):


bins = [i for i in range(0,int(concat_df['Time Delta Reformatted'].iloc[-1].split(':')[0])+24,24)]

labels = [f'{i}-{i+24}hrs' for i in range(0,int(concat_df['Time Delta Reformatted'].iloc[-1].split(':')[0]),24)]

concat_df['Bin'] = pd.cut(concat_df['Hours Since Start'], bins, labels=labels, right=False)

# %%
concat_df.head()
# Out:
#   MM:DD:YYYY hh:mm:ss Library_Version Session_type  Device_Number  \
# 0 2022-06-16 14:14:23          1.12.0   ClosedEcon             13
# 1 2022-06-16 14:14:41          1.12.0   ClosedEcon             13
# 2 2022-06-16 14:14:49          1.12.0   ClosedEcon             13
# 3 2022-06-16 15:27:35          1.12.0   ClosedEcon             13
# 4 2022-06-16 15:27:36          1.12.0   ClosedEcon             13
#
#    Battery_Voltage  Motor_Turns  FR   Event Active_Poke  Left_Poke_Count  \
# 0             4.01          NaN   1   Right        Left                0
# 1             4.01          NaN   1    Left        Left                1
# 2             4.01          1.0   1  Pellet        Left                1
# 3             4.00          NaN   1    Left        Left                2
# 4             4.00          1.0   1  Pellet        Left                2
#
#    Right_Poke_Count  Pellet_Count  Block_Pellet_Count Retrieval_Time  \
# 0                 1             0                   0            NaN
# 1                 1             0                   0            NaN
# 2                 1             1                   1           6.91
# 3                 1             1                   0            NaN
# 4                 1             2                   1           0.52
#
#    InterPelletInterval  Poke_Time      Time Delta Time Delta Reformatted  \
# 0                  NaN       0.22 0 days 02:14:23               02:14:23
# 1                  NaN       0.10 0 days 02:14:41               02:14:41
# 2                  NaN        NaN 0 days 02:14:49               02:14:49
# 3                  NaN       0.40 0 days 03:27:35               03:27:35
# 4               4367.0        NaN 0 days 03:27:36               03:27:36
#
#    Hours Since Start      Bin
# 0                  2  0-24hrs
# 1                  2  0-24hrs
# 2                  2  0-24hrs
# 3                  3  0-24hrs
# 4                  3  0-24hrs

# %% [markdown]
# ### Make bins based on those times

# %%
# bins = [10, 11, 12, 13, 14]
# labels = ['hour 1', 'hour 2', 'hour 3', 'hour 4']
# events = ['Left', 'Right', 'Pellet', 'LeftWithPellet', 'RightWithPellet']

# %% [markdown]
# ### Aggregate based on the results

# %%
concat_df.loc[(concat_df['Event'] == 'Right') | (concat_df['Event'] == 'Left') | (concat_df['Event'] == 'Pellet') | (concat_df['Event']=='LeftWithPellet') | (concat_df['Event']=='RightWithPellet'), 'Event Binary'] = 1

# %%
nt_df = pd.DataFrame(concat_df[['Bin', 'Event', 'Event Binary']].groupby(['Bin','Event']).sum())
nt_df
# Out:
#                             Event Binary
# Bin        Event
# 0-24hrs    Left                   1642.0
#            LeftWithPellet            1.0
#            Pellet                  134.0
#            Right                    55.0
#            RightWithPellet           0.0
# 24-48hrs   Left                   2397.0
#            LeftWithPellet            0.0
#            Pellet                  176.0
#            Right                     8.0
#            RightWithPellet           0.0
# 48-72hrs   Left                   1214.0
#            LeftWithPellet            1.0
#            Pellet                  176.0
#            Right                    14.0
#            RightWithPellet           0.0
# 72-96hrs   Left                   1343.0
#            LeftWithPellet            0.0
#            Pellet                  152.0
#            Right                    22.0
#            RightWithPellet           0.0
# 96-120hrs  Left                    982.0
#            LeftWithPellet            0.0
#            Pellet                  155.0
#            Right                    11.0
#            RightWithPellet           1.0
# 120-144hrs Left                   1098.0
#            LeftWithPellet            0.0
#            Pellet                  149.0
#            Right                     5.0
#            RightWithPellet           0.0
# 144-168hrs Left                   1085.0
#            LeftWithPellet            1.0
#            Pellet                  131.0
#            Right                    10.0
#            RightWithPellet           0.0
# 168-192hrs Left                    711.0
#            LeftWithPellet          340.0
#            Pellet                  129.0
#            Right                    10.0
#            RightWithPellet           0.0
# 192-216hrs Left                     44.0
#            LeftWithPellet            4.0
#            Pellet                   15.0
#            Right                     5.0
#            RightWithPellet           2.0
# 216-240hrs Left                      1.0
#            LeftWithPellet            0.0
#            Pellet                    1.0
#            Right                     1.0
#            RightWithPellet           0.0
# 240-264hrs Left                     21.0
#            LeftWithPellet           13.0
#            Pellet                    9.0
#            Right                     6.0
#            RightWithPellet           2.0
# 264-288hrs Left                    210.0
#            LeftWithPellet            0.0
#            Pellet                   61.0
#            Right                    22.0
#            RightWithPellet           0.0
# 288-312hrs Left                    188.0
#            LeftWithPellet            1.0
#            Pellet                   58.0
#            Right                    17.0
#            RightWithPellet           0.0
# 312-336hrs Left                     28.0
#            LeftWithPellet            1.0
#            Pellet                   14.0
#            Right                     0.0
#            RightWithPellet           0.0
# 336-360hrs Left                    847.0
#            LeftWithPellet            1.0
#            Pellet                  124.0
#            Right                    64.0
#            RightWithPellet           1.0
# 360-384hrs Left                    700.0
#            LeftWithPellet            0.0
#            Pellet                  115.0
#            Right                    17.0
#            RightWithPellet           0.0
# 384-408hrs Left                    923.0
#            LeftWithPellet            0.0
#            Pellet                  139.0
#            Right                    14.0
#            RightWithPellet           1.0
# 408-432hrs Left                    679.0
#            LeftWithPellet            0.0
#            Pellet                  123.0
#            Right                     8.0
#            RightWithPellet           0.0
# 432-456hrs Left                    622.0
#            LeftWithPellet            0.0
#            Pellet                  122.0
#            Right                     8.0
#            RightWithPellet           0.0
# 456-480hrs Left                   1038.0
#            LeftWithPellet            0.0
#            Pellet                  125.0
#            Right                     4.0
#            RightWithPellet           0.0

# %%
tdf = nt_df.groupby(['Bin','Event'])['Event Binary'].first().unstack(fill_value=1).rename_axis(None)
tdf['Pokes Per Pellet'] = tdf['Left']/tdf['Pellet']
tdf['Pellet (kcal)'] = tdf['Pellet']*0.066
tdf['Max FR'] = concat_df.groupby('Bin')['FR'].max()
tdf['Max FR Timestamp'] = concat_df.groupby('Bin')['MM:DD:YYYY hh:mm:ss','FR'].max()['MM:DD:YYYY hh:mm:ss']

tdf
# Out:
# /var/folders/ns/ryjnxrk12jj4nhs8gn4qnfh40000gn/T/ipykernel_3412/3200597951.py:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   tdf['Max FR Timestamp'] = concat_df.groupby('Bin')['MM:DD:YYYY hh:mm:ss','FR'].max()['MM:DD:YYYY hh:mm:ss']
# Event         Left  LeftWithPellet  Pellet  Right  RightWithPellet  \
# 0-24hrs     1642.0             1.0   134.0   55.0              0.0
# 24-48hrs    2397.0             0.0   176.0    8.0              0.0
# 48-72hrs    1214.0             1.0   176.0   14.0              0.0
# 72-96hrs    1343.0             0.0   152.0   22.0              0.0
# 96-120hrs    982.0             0.0   155.0   11.0              1.0
# 120-144hrs  1098.0             0.0   149.0    5.0              0.0
# 144-168hrs  1085.0             1.0   131.0   10.0              0.0
# 168-192hrs   711.0           340.0   129.0   10.0              0.0
# 192-216hrs    44.0             4.0    15.0    5.0              2.0
# 216-240hrs     1.0             0.0     1.0    1.0              0.0
# 240-264hrs    21.0            13.0     9.0    6.0              2.0
# 264-288hrs   210.0             0.0    61.0   22.0              0.0
# 288-312hrs   188.0             1.0    58.0   17.0              0.0
# 312-336hrs    28.0             1.0    14.0    0.0              0.0
# 336-360hrs   847.0             1.0   124.0   64.0              1.0
# 360-384hrs   700.0             0.0   115.0   17.0              0.0
# 384-408hrs   923.0             0.0   139.0   14.0              1.0
# 408-432hrs   679.0             0.0   123.0    8.0              0.0
# 432-456hrs   622.0             0.0   122.0    8.0              0.0
# 456-480hrs  1038.0             0.0   125.0    4.0              0.0
#
# Event       Pokes Per Pellet  Pellet (kcal)  Max FR    Max FR Timestamp
# 0-24hrs            12.253731          8.844      46 2022-06-17 11:21:10
# 24-48hrs           13.619318         11.616      52 2022-06-18 11:57:26
# 48-72hrs            6.897727         11.616      31 2022-06-19 11:48:45
# 72-96hrs            8.835526         10.032      39 2022-06-20 11:19:56
# 96-120hrs           6.335484         10.230      30 2022-06-21 11:25:00
# 120-144hrs          7.369128          9.834      33 2022-06-22 09:26:00
# 144-168hrs          8.282443          8.646      35 2022-06-23 10:42:15
# 168-192hrs          5.511628          8.514      22 2022-06-24 10:53:45
# 192-216hrs          2.933333          0.990       8 2022-06-25 05:32:05
# 216-240hrs          1.000000          0.066       1 2022-06-25 20:53:50
# 240-264hrs          2.333333          0.594       4 2022-06-27 10:48:51
# 264-288hrs          3.442623          4.026      13 2022-06-28 11:54:19
# 288-312hrs          3.241379          3.828      12 2022-06-29 11:22:55
# 312-336hrs          2.000000          0.924       4 2022-06-29 19:55:58
# 336-360hrs          6.830645          8.184      27 2022-07-01 11:48:55
# 360-384hrs          6.086957          7.590      22 2022-07-02 10:48:02
# 384-408hrs          6.640288          9.174      29 2022-07-03 11:59:41
# 408-432hrs          5.520325          8.118      23 2022-07-04 10:29:58
# 432-456hrs          5.098361          8.052      19 2022-07-05 10:35:09
# 456-480hrs          8.304000          8.250      29 2022-07-06 11:16:53

# %%
# Plus 1 of whatever the start time is as a label
# Left, right, pellet, leftwithpellet, rightwithpellet

# %%
# concat_df.loc[concat_df.groupby(['Bin'])['FR'].idxmax()]

idx = concat_df.groupby(['Bin'])['FR'].max() == concat_df['MM:DD:YYYY hh:mm:ss']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/kevinmcpherson/github-projects/fed-scripts/notebooks/test_playground.ipynb Cell 27 in <module>
#       <a href='vscode-notebook-cell:/Users/kevinmcpherson/github-projects/fed-scripts/notebooks/test_playground.ipynb#X56sZmlsZQ%3D%3D?line=0'>1</a> # concat_df.loc[concat_df.groupby(['Bin'])['FR'].idxmax()]
# ----> <a href='vscode-notebook-cell:/Users/kevinmcpherson/github-projects/fed-scripts/notebooks/test_playground.ipynb#X56sZmlsZQ%3D%3D?line=2'>3</a> idx = concat_df.groupby(['Bin'])['FR'].max() == concat_df['MM:DD:YYYY hh:mm:ss']
#
# File ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/pandas/core/ops/common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/pandas/core/series.py:5617, in Series._cmp_method(self, other, op)
#    5614 res_name = ops.get_op_result_name(self, other)
#    5616 if isinstance(other, Series) and not self._indexed_same(other):
# -> 5617     raise ValueError("Can only compare identically-labeled Series objects")
#    5619 lvalues = self._values
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#
# ValueError: Can only compare identically-labeled Series objects

# %%
concat_df.groupby('Bin')['MM:DD:YYYY hh:mm:ss','FR'].max()['MM:DD:YYYY hh:mm:ss']
# Out:
# /var/folders/ns/ryjnxrk12jj4nhs8gn4qnfh40000gn/T/ipykernel_3412/2993834148.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   concat_df.groupby('Bin')['MM:DD:YYYY hh:mm:ss','FR'].max()['MM:DD:YYYY hh:mm:ss']
# Bin
# 0-24hrs      2022-06-17 11:21:10
# 24-48hrs     2022-06-18 11:57:26
# 48-72hrs     2022-06-19 11:48:45
# 72-96hrs     2022-06-20 11:19:56
# 96-120hrs    2022-06-21 11:25:00
# 120-144hrs   2022-06-22 09:26:00
# 144-168hrs   2022-06-23 10:42:15
# 168-192hrs   2022-06-24 10:53:45
# 192-216hrs   2022-06-25 05:32:05
# 216-240hrs   2022-06-25 20:53:50
# 240-264hrs   2022-06-27 10:48:51
# 264-288hrs   2022-06-28 11:54:19
# 288-312hrs   2022-06-29 11:22:55
# 312-336hrs   2022-06-29 19:55:58
# 336-360hrs   2022-07-01 11:48:55
# 360-384hrs   2022-07-02 10:48:02
# 384-408hrs   2022-07-03 11:59:41
# 408-432hrs   2022-07-04 10:29:58
# 432-456hrs   2022-07-05 10:35:09
# 456-480hrs   2022-07-06 11:16:53
# Name: MM:DD:YYYY hh:mm:ss, dtype: datetime64[ns]
